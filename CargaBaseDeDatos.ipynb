-- %% [markdown]
-- # [ProyectoEldoria]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ProyectoEldoria]    Script Date: 24/03/2024 20:04:00 ******/
CREATE DATABASE [ProyectoEldoria]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ProyectoEldoria', FILENAME = N'C:\Users\Usuario\ProyectoEldoria.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ProyectoEldoria_log', FILENAME = N'C:\Users\Usuario\ProyectoEldoria_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [ProyectoEldoria] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ProyectoEldoria].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ProyectoEldoria] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET ARITHABORT OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [ProyectoEldoria] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ProyectoEldoria] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ProyectoEldoria] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET  ENABLE_BROKER 
GO
ALTER DATABASE [ProyectoEldoria] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ProyectoEldoria] SET READ_COMMITTED_SNAPSHOT ON 
GO
ALTER DATABASE [ProyectoEldoria] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [ProyectoEldoria] SET  MULTI_USER 
GO
ALTER DATABASE [ProyectoEldoria] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ProyectoEldoria] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ProyectoEldoria] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ProyectoEldoria] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ProyectoEldoria] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ProyectoEldoria] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [ProyectoEldoria] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [ProyectoEldoria]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 24/03/2024 20:04:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Aventurero]

-- %%
/****** Object:  Table [dbo].[Aventurero]    Script Date: 24/03/2024 20:04:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Aventurero](
	[Codigo] [int] IDENTITY(1,1) NOT NULL,
	[FechaNacimiento] [date] NOT NULL,
	[Correo] [nvarchar](max) NOT NULL,
	[Clase] [nvarchar](max) NOT NULL,
	[Raza] [nvarchar](max) NOT NULL,
	[Elemento] [nvarchar](max) NOT NULL,
	[Companiero] [nvarchar](max) NOT NULL,
	[Habilidades] [nvarchar](max) NOT NULL,
	[Nombre] [nvarchar](max) NOT NULL,
	[Apellido] [nvarchar](max) NOT NULL,
	[Retrato] [nvarchar](max) NOT NULL,
	[Origen] [nvarchar](max) NOT NULL,
	[Mentor] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_Aventurero] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mentor]

-- %%
/****** Object:  Table [dbo].[Mentor]    Script Date: 24/03/2024 20:04:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mentor](
	[Codigo] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](max) NOT NULL,
	[Apellido] [nvarchar](max) NOT NULL,
	[Retrato] [nvarchar](max) NOT NULL,
	[Origen] [nvarchar](max) NOT NULL,
	[Especialidad] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_Mentor] PRIMARY KEY CLUSTERED 
(
	[Codigo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Aventurer__Mento__70DDC3D8]

-- %%
ALTER TABLE [dbo].[Aventurero] ADD  DEFAULT (N'') FOR [Mentor]
GO

-- %% [markdown]
-- # [ProyectoEldoria]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ProyectoEldoria] SET  READ_WRITE 
GO
